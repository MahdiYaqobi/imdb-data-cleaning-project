# %% [markdown]
# # IMDB Top 1000 Movies Dataset Analysis

# %%
# import necessary libraries for data manipulation and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns',200)

# %%
# Load the dataset from the CSV file into a pandas DataFrame
df=pd.read_csv('../data/raw/imdb_top_1000.csv')

# %%
# Display the first few rows to inspect the data
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
# Display information about the dataframe, including data types and non-null counts
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   str
#  1   Series_Title   1000 non-null   str
#  2   Released_Year  1000 non-null   str
#  3   Certificate    899 non-null    str
#  4   Runtime        1000 non-null   str
#  5   Genre          1000 non-null   str
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   str
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   str
#  10  Star1          1000 non-null   str
#  11  Star2          1000 non-null   str
#  12  Star3          1000 non-null   str
#  13  Star4          1000 non-null   str
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    str
# dtypes: float64(2), int64(1), str(13)
# memory usage: 125.1 KB

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
# check if any duplicate rows exist
df.duplicated().sum()  # True or Falswe
# Out:
# np.int64(0)

# %%
# Display summary statistics for numerical columns
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
# Drop columns that are not relevant for analysis
df = df.drop(columns=[
    "Poster_Link",
    "Overview",
    "Certificate",
    "Star2",
    "Star3",
    "Star4"
])

# %% [markdown]
# ## Initial Data Inspection
#
# ### Dataest Shape
# the dataset contains **1000 rows** and **10 colunms**.
#
# ### Missing Values
# - `Meta_score` has missing values
# - `Gross` has missing values
#
# ### Data Type Issues
# - `Released_Year` should be numeric but contains text values
# - `Gross` should be numeric but contains non-numeric values
#
# ### Low vote Movies
# Some movies have very low number of votes and may not be reliable for analysis.
#
# ### Summary
# The dataset requires data cleaning including:
# - Handling missing values
# - Fixing data types
# - filterinf low-vote movies

# %%
# standardize column names by converting to lowercase and stripping whitespace
df.columns=df.columns.str.lower().str.strip()

# %%
# convert 'released_year' to numeric, handling errors by coercing to NaN
df['released_year']=pd.to_numeric(df['released_year'],errors='coerce')

df=df.dropna(subset=['released_year'])
df['released_year']=df['released_year'].astype(int)

# %%
# clean 'runtime' column by removing 'min' and converting to numeric.
df['runtime']=df['runtime'].str.replace(' min','',regex=False)
df['runtime']=pd.to_numeric(df['runtime'],errors='coerce')

# %%
# clean 'gross' column by removing commas and converting to numeric
df['gross']=df['gross'].str.replace(',','',regex=False)
df['gross']=pd.to_numeric(df['gross'],errors='coerce')

# %%
# standardize 'genre' column by converting to lowercase and stripping whitespace
df['genre']=df['genre'].str.lower().str.strip()

# %%
# handle missing values in 'meta_score' and 'gross' by filling with the median value of each column
df['meta_score']=df['meta_score'].fillna(df['meta_score'].median())
df['gross']=df['gross'].fillna(df['gross'].median())

# %%
# final check for missing values and data types after cleaning
df.isnull().sum()
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   series_title   999 non-null    str
#  1   released_year  999 non-null    int64
#  2   runtime        999 non-null    int64
#  3   genre          999 non-null    str
#  4   imdb_rating    999 non-null    float64
#  5   meta_score     999 non-null    float64
#  6   director       999 non-null    str
#  7   star1          999 non-null    str
#  8   no_of_votes    999 non-null    int64
#  9   gross          999 non-null    float64
# dtypes: float64(3), int64(3), str(4)
# memory usage: 85.9 KB
#        released_year     runtime  imdb_rating  meta_score   no_of_votes  \
# count     999.000000  999.000000   999.000000  999.000000  9.990000e+02
# mean     1991.217217  122.873874     7.949650   78.134134  2.736974e+05
# std        23.297025   28.102520     0.275407   11.373863  3.275366e+05
# ...

# %%
# create a new column 'decade' by extractig the decade from 'released_year' 
df['decade']=(df['released_year']//10)*10

# create a new cloumn 'released_period' by categorical periods ('old' ,'middle', 'new') based on 'released_year'
df['released_period']=pd.cut(
    df['released_year'],
    bins=[1900,1980,2000,2026],
    labels=['old','middle','new']
)

# %%
# create a new column 'rating_category' by categorizing 'imdb_rating' into different categories
df['rating_category']=pd.cut(
    df['imdb_rating'],
    bins=[0,5,7,8.5,10],
    labels=['low','average','high','excellent']
)

# create a new column 'gross_category' by categorizing 'gross' into different categories
df['gross_category']=pd.cut(
    df['gross'],
    bins=[0,50000000,200000000,1000000000],
    labels=['low','medium','high']
)

# create a new column 'vote_per_million_gross' by calculating the number of votes per million dollars of gross revenue
df['vote_per_million_gross'] = df['no_of_votes'] / (df['gross'] / 1_000_000)
df['vote_per_million_gross'] = df['vote_per_million_gross'].replace([np.inf, -np.inf], np.nan)

# %%
# create a new column 'main_genre' by extracting the first genre from the 'genre' column,
#  and a new column 'genre_count' by counting the number of genres listed for each movie
df['main_genre']=df['genre'].str.split(',').str[0]
df['genre_count']=df['genre'].str.count(',')+1

# %% [markdown]
# ## Distribution of IMDB Rating
#
# Plot a histogram and KDE for 'imdb_rating' column

# %%
# histogram and KDE for 'imdb_rating' column 
plt.figure(figsize=(8,5))
sns.histplot(df['imdb_rating'],bins=20,kde=True)
plt.title('Distribution of IMDB Ratings')
plt.xlabel('IMDB Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Insight
#
# Most movies in the dataset have IMDB ratings between 7 and 8.
# Very low-rated are uncommon because the dataset contains IMDB Top 1000 movies.
# The distribution is slightly left-skewed, meaning the highly rated movies dominate the dataset.

# %% [markdown]
# ## Distribution of Runtime
#
# Plot a boxplot for 'runtime' column

# %%
# boxplot for 'runtime' column
plt.figure(figsize=(8,5))
sns.boxplot(x=df['runtime'])
plt.title('boxplot of Runtime')
plt.show()

# %% [markdown]
# ### Insight
#
# The boxplot for movie runtime shows that most IMDB Top 1000 movies have runtimes clustered between approximately 100 and 150 minutes. There are a few outliers with much longer runtimes, indicating that while most popular movies tend to follow a standard length, some exceptional cases are significantly longer. The distribution also suggests a slight right skew, with more movies having runtimes above the median than below.

# %% [markdown]
# ## Top 10 Genres
#
# Plot a barplot for 10 genre

# %%
top_genres = df['main_genre'].value_counts().head(10)

# barplot for top 10 genres
plt.figure(figsize=(10,6))
sns.barplot(x=top_genres.values, y=top_genres.index)
plt.title('Top 10 Genres')
plt.show()

# %% [markdown]
# ### Insight
#
#
# Drama is the most dominant genre in the dataset, appearing in 289 movies, significantly more than any other genre. Action and Comedy are also highly represented, suggesting that these genres are consistently popular among IMDb Top 1000 movies. The presence of genres like Crime, Biography, and Mystery indicates that audiences and critics tend to favor story-driven and emotionally engaging films.

# %% [markdown]
# ## Votes vs Rating
#
# Is there relationshep between number of Votes and IMDB Ratings ?

# %%
# scatter plot of 'imdb_rating' vs 'no_of_votes'
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['imdb_rating'],y=df['no_of_votes'])
plt.title('IMDB Rating vs Number of Votes')
plt.show()

# %% [markdown]
# ## Insight
#
# - There is at best a weak positive relationship: movies with very high vote counts tend to cluster around higher ratings (roughly 7.5–9.5), but ratings show large variability at all vote levels.
# - Low-vote movies are spread across the full rating range, indicating that vote volume alone is not a reliable proxy for quality.
# - The plot shows heteroscedasticity and many outliers (a few titles with extremely high votes); using a log scale for votes or computing Spearman correlation would clarify the trend.
# - Interpretation caveat: vote counts are influenced by popularity, distribution and age of the film, so adjust analyses for these factors before drawing causal conclusions.

# %% [markdown]
# ## Runtime vs IMDB Rating
#
# Do longer movies receive higher IMDB rating ?

# %%
# scatter plot of 'runtime' vs 'imdb_rating'
plt.figure(figsize=(8,5))
sns.scatterplot(data=df , x='runtime', y='imdb_rating')
plt.title('Runtime vs IMDB Rating')
plt.xlabel('Runtime (minutes)')
plt.ylabel('IMDB Rating')
plt.show()

# %% [markdown]
# ### Insight
#
# There is a week positive relationship between movies runtime and IMDB ratings.
# Longer movies tend to receive slightly higher ratings on average, but the relationship is not strong due to the large spread of
# data points.

# %% [markdown]
# ## To see the Trend

# %%
# regression plot to see the trend between 'runtime' and 'imdb_rating'
sns.regplot(
    data=df,
    x='runtime',
    y='imdb_rating',   
)
plt.show()

# %% [markdown]
# ### Insight
#
# The regression plot show that there is a week positive relationship.

# %% [markdown]
# ## Correlation Heatmap
#
# Plot heatmap of the correlation matrix for numerical features.

# %%
# Correlation Heatmap
plt.figure(figsize=(10,8))
df_corr = df.corr(numeric_only=True)
sns.heatmap(df_corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ### Insight
#
# The headmap show that most numerical features have week correlation with each other.
# However 'gross' and 'no_of_votes' have a relatively strong positive relationship,suggesting that movies with higher popularity and audience engagement tend to generate higher revenue.

# %% [markdown]
# ## Top Directors by Average Rating
#
# Create a barplot to see the top directors

# %%
# bar plot of top 10 directors by average IMDB rating
top_directors = df.groupby('director')['imdb_rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_directors.values, y=top_directors.index)
plt.title('Top 10 Directors by Average IMDB Rating')
plt.xlabel('Average IMDB Rating')
plt.show()
top_directors
# Out:
# director
# Frank Darabont        8.95
# Lana Wachowski        8.70
# Irvin Kershner        8.70
# Masaki Kobayashi      8.60
# Fernando Meirelles    8.60
# George Lucas          8.60
# Sudha Kongara         8.60
# Thomas Kail           8.60
# Roberto Benigni       8.60
# Milos Forman          8.50
# Name: imdb_rating, dtype: float64

# %% [markdown]
# ### Insight
#
# The chart shows the top 10 directors based on average IMDb ratings. Frank Darabont ranks first with an average rating of 8.95, followed by Lana Wachowski and Irvin Kershner with average ratings around 8.7.
#
# All directors in the ranking have average IMDb ratings above 8, and the differences between them are relatively small. This is likely because the dataset contains only IMDb Top 1000 movies, which are generally highly rated.

# %% [markdown]
# ## Moves Per Decade
#
# Plot a bar chart showing the number of movies released in each decade.

# %%
# movie per decade
movies_per_decade=df['decade'].value_counts().sort_values()

plt.figure(figsize=(10,6))

sns.barplot(x=movies_per_decade.index, y=movies_per_decade.values)
plt.title('Number of Movies Released Per Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Movies')
plt.show()

# %% [markdown]
# ### Insight
#
# The chart shows the number of movies released per decade. The 2010s rank first with more than 140 movies, followed by the 2000s.
#
# Movie production in the dataset generally increases over time, with a clear upward trend from older decades to the 2010s. However, the number of movies in the 2020s drops significantly, likely because the dataset was collected during the early years of the decade.

# %% [markdown]
# ## Highest Grossing Genre
#
# Plot a barchart that shows the top 10 main genres

# %%
# average gross revenue by main genre
genre_gross = df.groupby('main_genre')['gross'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))

sns.barplot(x=genre_gross.values, y=genre_gross.index)
plt.title('Average Gross Revenue by Main Genre')
plt.xlabel('Average Gross Revenue')
plt.ylabel('Main Genre')
plt.show()

# %% [markdown]
# ### Insight
#
# The chart shows the average gross revenue by main genre. Family movies rank first, generating the highest average revenue, followed by Action and Animation movies.
#
# This suggests that family-oriented and action-packed films tend to attract larger audiences and achieve greater commercial success. These genres are often designed for broad audience appeal, which may contribute to their higher box office performance.

# %% [markdown]
# ## Meta Score vs IMDB Rating
#
# Plot a scatter plot to show the relationship between meta score and imdb rating

# %%
# meta score vs imdb rating
plt.figure(figsize=(8,5))

sns.scatterplot(
    x=df['meta_score'],
    y=df['imdb_rating']
)
plt.title('Meta Score vs IMDb Rating')
plt.xlabel('Meta Score')
plt.ylabel('IMDb Rating')
plt.show()

# %% [markdown]
# ### Insight
#
# The plot shows a weak positive relationship between Meta Score and IMDb ratings. Movies with higher critic scores tend to receive slightly higher IMDb ratings as well.
#
# Most data points suggest that critic reviews and audience ratings are generally aligned, although the relationship is not very strong. The plot also contains a few outliers where movies achieve exceptionally high scores in both Meta Score and IMDb ratings.

# %%
# save the cleaned dataframe to a new CSV file
df.to_csv("../data/processed/imdb_clean.csv", index=False)
